0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=125.0, right=125.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=126.0, right=126.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=127.0, right=127.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=128.0, right=128.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=129.0, right=129.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=130.0, right=130.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=131.0, right=131.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=132.0, right=132.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=133.0, right=133.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=134.0, right=134.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=135.0, right=135.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=136.0, right=136.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=137.0, right=137.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=138.0, right=138.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=139.0, right=139.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=140.0, right=140.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=141.0, right=141.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=142.0, right=142.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=143.0, right=143.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=144.0, right=144.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=145.0, right=145.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=146.0, right=146.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=147.0, right=147.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=148.0, right=148.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=149.0, right=149.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=150.0, right=150.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=151.0, right=151.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=152.0, right=152.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=153.0, right=153.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=154.0, right=154.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=155.0, right=155.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=156.0, right=156.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=157.0, right=157.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=158.0, right=158.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=159.0, right=159.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=160.0, right=160.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=161.0, right=161.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=162.0, right=162.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=163.0, right=163.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=164.0, right=164.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=165.0, right=165.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=166.0, right=166.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=167.0, right=167.0
#   'left=%s, right=%s') % (left, right))
# ...
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=191.0, right=191.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=192.0, right=192.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=193.0, right=193.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=194.0, right=194.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=195.0, right=195.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=196.0, right=196.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=197.0, right=197.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=198.0, right=198.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=199.0, right=199.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=200.0, right=200.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=201.0, right=201.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=202.0, right=202.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=203.0, right=203.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=204.0, right=204.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=205.0, right=205.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=206.0, right=206.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=207.0, right=207.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=208.0, right=208.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=209.0, right=209.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=210.0, right=210.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=211.0, right=211.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=212.0, right=212.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=213.0, right=213.0
#   'left=%s, right=%s') % (left, right))
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=214.0, right=214.0
#   'left=%s, right=%s') % (left, right))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-60123db478d8> in <module>()
#      14
#      15 get_ipython().magic('matplotlib inline')
# ---> 16 df.plot()
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/groupby.py in __call__(self, *args, **kwargs)
#     347             return self.plot(*args, **kwargs)
#     348         f.__name__ = 'plot'
# --> 349         return self._groupby.apply(f)
#     350
#     351     def __getattr__(self, name):
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     714         # ignore SettingWithCopy here in case the user mutates
#     715         with option_context('mode.chained_assignment', None):
# --> 716             return self._python_apply_general(f)
#     717
#     718     def _python_apply_general(self, f):
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     718     def _python_apply_general(self, f):
#     719         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 720                                                    self.axis)
#     721
#     722         return self._wrap_applied_output(
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, f, data, axis)
#    1727             # group might be modified
#    1728             group_axes = _get_axes(group)
# -> 1729             res = f(group)
#    1730             if not _is_indexed_like(res, group_axes):
#    1731                 mutated = True
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/core/groupby.py in f(self)
#     345     def __call__(self, *args, **kwargs):
#     346         def f(self):
# --> 347             return self.plot(*args, **kwargs)
#     348         f.__name__ = 'plot'
#     349         return self._groupby.apply(f)
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1855                  yerr=yerr, xerr=xerr,
#    1856                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1857                  **kwds)
#    1858
#    1859
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1680         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1681
# -> 1682     plot_obj.generate()
#    1683     plot_obj.draw()
#    1684     return plot_obj.result
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     235         self._args_adjust()
#     236         self._compute_plot_data()
# --> 237         self._setup_subplots()
#     238         self._make_plot()
#     239         self._add_table()
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/pandas/plotting/_core.py in _setup_subplots(self)
#     287             if self.ax is None:
#     288                 fig = self.plt.figure(figsize=self.figsize)
# --> 289                 axes = fig.add_subplot(111)
#     290             else:
#     291                 fig = self.ax.get_figure()
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     549
#     550         self._connected = {}  # a dict from events to (id, func)
# --> 551         self.cla()
#     552         # funcs used to format x and y - fall back on major formatters
#     553         self.fmt_xdata = None
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axes/_base.py in cla(self)
#     982         self.yaxis.cla()
#     983         for name, spine in six.iteritems(self.spines):
# --> 984             spine.cla()
#     985
#     986         self.ignore_existing_data_limits = True
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/spines.py in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axis.py in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axis.py in reset_ticks(self)
#     773
#     774         self.majorTicks.extend([self._get_tick(major=True)])
# --> 775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#     777         self._lastNumMinorTicks = 1
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2058         else:
#    2059             tick_kw = self._minor_tick_kw
# -> 2060         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2061
#    2062     def _get_label(self):
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     554                           markersize=self._size,
#     555                           markeredgewidth=self._width,
# --> 556                           zorder=self._zorder)
#     557         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     558         self._set_artist_props(l)
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         self._color = None
#     403         self.set_color(color)
# --> 404         self._marker = MarkerStyle()
#     405         self.set_marker(marker)
#     406
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     270
#     271         self._marker = marker
# --> 272         self._recache()
#     273
#     274     def get_path(self):
#
# /Users/utopia/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/matplotlib/markers.py in _recache(self)
#     198
#     199     def _recache(self):
# --> 200         self._path = Path(np.empty((0, 2)))
#     201         self._transform = IdentityTransform()
#     202         self._alt_path = None
#
# KeyboardInterrupt:
